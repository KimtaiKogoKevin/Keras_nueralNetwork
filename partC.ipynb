# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
from sklearn.metrics import mean_squared_error

import pandas as pd
from sklearn.model_selection import train_test_split
  
# importing data
df = pd.read_csv('concrete_data.csv')
  
# head of the data
#print(df.head())

#prepare the X independent   variables 

X1 = df['Cement']
X2=df['Blast Furnace Slag']
X3 =df['Fly Ash']
X4=df['Water']
X5=df['Superplasticizer']
X6=df['Coarse Aggregate']
X7=df['Fine Aggregate']
X8=df['Age']
X = pd.concat([X1,X2,X3,X4,X5,X6,X7,X8], axis=1)
#X.head(20)
# Out:
# 2023-07-21 23:00:57.041325: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-07-21 23:00:57.226614: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-07-21 23:00:57.229222: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-21 23:01:00.545679: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
#prepare the Y  dependent variables 
Y1 = df['Strength']
Y = pd.concat([Y1], axis=1)
#Y.head(20)

# %%
#Split the data
x_train, x_test,y_train,y_test = train_test_split(X,Y,test_size =0.3)
# print the data
# x_train
# Manually normalize the data for the indepnedent x variables by subtracting the mean and dividing by the standard deviation
x_train_normalized = (x_train - np.mean(x_train, axis=0)) / np.std(x_train, axis=0)
x_test_normalized = (x_test - np.mean(x_train, axis=0)) / np.std(x_train, axis=0)

# Manually normalize the data for the dependent y variables by subtracting the mean and dividing by the standard deviation
y_train_normalized = (y_train - np.mean(y_train, axis=0)) / np.std(y_train, axis=0)
y_test_normalized = (y_test - np.mean(y_train, axis=0)) / np.std(y_train, axis=0)

# Create a neural network model
model = Sequential()
model.add(Dense(10, input_dim=x_train_normalized.shape[1], activation='relu',use_bias=True))  # Hidden layer with 10 nodes and ReLU activation
model.add(Dense(1, activation='sigmoid',use_bias=True))  # Output layer with 1 node and sigmoid activation

# Compile the model
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])

# Train the model with 100 epochs
epochs = 100
mse_list=[]
y_pred_list=[]
for epoch in range(epochs):
    model.fit(x_train_normalized,y_train,epochs=1,verbose=0)
    y_pred = model.predict(x_test_normalized)
    y_pred_list.append(y_pred)
    # print("y_pred : ",y_pred)
    #evaluate model on the normalized test data
    mse = mean_squared_error(y_test_normalized,y_pred)
    mse_list.append(mse)
    print(f"Epoch {epoch +1} , Mean Squared Error: {mse}")
#   List of Mean Squared errors for 50 epochs
print(mse_list) 

# Calculate the mean
mean_mse = np.mean(mse_list)

# Calculate the standard deviation
std_dev_mse = np.std(mse_list)

# Print the results
print("Mean: ", mean_mse)
print("Standard Deviation: ", std_dev_mse)
# print("y_prediction list: " ,y_pred_list)


#observation , decreased mean squared error after normalization
# Out:
# 10/10 [==============================] - 0s 5ms/step
# Epoch 1 , Mean Squared Error: 1.4148662843623285
# 10/10 [==============================] - 0s 8ms/step
# Epoch 2 , Mean Squared Error: 1.464862382842407
# 10/10 [==============================] - 0s 5ms/step
# Epoch 3 , Mean Squared Error: 1.5146606597082681
# 10/10 [==============================] - 0s 6ms/step
# Epoch 4 , Mean Squared Error: 1.565791148120289
# 10/10 [==============================] - 0s 7ms/step
# Epoch 5 , Mean Squared Error: 1.6145038130192737
# 10/10 [==============================] - 0s 5ms/step
# Epoch 6 , Mean Squared Error: 1.6624903573679861
# 10/10 [==============================] - 0s 21ms/step
# Epoch 7 , Mean Squared Error: 1.7085538077377365
# 10/10 [==============================] - 0s 10ms/step
# Epoch 8 , Mean Squared Error: 1.7516638969485079
# 10/10 [==============================] - 0s 5ms/step
# Epoch 9 , Mean Squared Error: 1.7914492016595132
# 10/10 [==============================] - 0s 6ms/step
# Epoch 10 , Mean Squared Error: 1.8278804940920237
# 10/10 [==============================] - 0s 5ms/step
# Epoch 11 , Mean Squared Error: 1.8600851176211517
# 10/10 [==============================] - 0s 6ms/step
# Epoch 12 , Mean Squared Error: 1.88887244226788
# 10/10 [==============================] - 0s 8ms/step
# Epoch 13 , Mean Squared Error: 1.9140142062368035
# 10/10 [==============================] - 0s 5ms/step
# Epoch 14 , Mean Squared Error: 1.936659357853367
# 10/10 [==============================] - 0s 5ms/step
# Epoch 15 , Mean Squared Error: 1.9562073133354372
# 10/10 [==============================] - 0s 5ms/step
# Epoch 16 , Mean Squared Error: 1.973708449368592
# 10/10 [==============================] - 0s 5ms/step
# Epoch 17 , Mean Squared Error: 1.9887116551354653
# 10/10 [==============================] - 0s 5ms/step
# Epoch 18 , Mean Squared Error: 2.002106179591207
# 10/10 [==============================] - 0s 9ms/step
# Epoch 19 , Mean Squared Error: 2.0138504916785713
# 10/10 [==============================] - 0s 5ms/step
# Epoch 20 , Mean Squared Error: 2.024371743159076
# 10/10 [==============================] - 0s 10ms/step
# Epoch 21 , Mean Squared Error: 2.033690317410211
# 10/10 [==============================] - 0s 8ms/step
# Epoch 22 , Mean Squared Error: 2.0418452135855234
# 10/10 [==============================] - 0s 9ms/step
# Epoch 23 , Mean Squared Error: 2.0491553995248424
# 10/10 [==============================] - 0s 7ms/step
# Epoch 24 , Mean Squared Error: 2.055558770782614
# 10/10 [==============================] - 0s 5ms/step
# Epoch 25 , Mean Squared Error: 2.0611689930708095
# 10/10 [==============================] - 0s 10ms/step
# Epoch 26 , Mean Squared Error: 2.066270268815467
# 10/10 [==============================] - 0s 7ms/step
# Epoch 27 , Mean Squared Error: 2.0708028112036656
# 10/10 [==============================] - 0s 10ms/step
# Epoch 28 , Mean Squared Error: 2.074887554806804
# 10/10 [==============================] - 0s 5ms/step
# Epoch 29 , Mean Squared Error: 2.0786184978109197
# 10/10 [==============================] - 0s 4ms/step
# Epoch 30 , Mean Squared Error: 2.0820008571231217
# 10/10 [==============================] - 0s 4ms/step
# Epoch 31 , Mean Squared Error: 2.084877514042026
# 10/10 [==============================] - 0s 4ms/step
# Epoch 32 , Mean Squared Error: 2.0876371217219756
# 10/10 [==============================] - 0s 5ms/step
# Epoch 33 , Mean Squared Error: 2.090126583006053
# 10/10 [==============================] - 0s 4ms/step
# Epoch 34 , Mean Squared Error: 2.0923837099442095
# 10/10 [==============================] - 0s 4ms/step
# Epoch 35 , Mean Squared Error: 2.0944070100124437
# 10/10 [==============================] - 0s 7ms/step
# Epoch 36 , Mean Squared Error: 2.0962743725425024
# 10/10 [==============================] - 0s 5ms/step
# Epoch 37 , Mean Squared Error: 2.0980066027170348
# 10/10 [==============================] - 0s 6ms/step
# Epoch 38 , Mean Squared Error: 2.0995951190734883
# 10/10 [==============================] - 0s 5ms/step
# Epoch 39 , Mean Squared Error: 2.1011046775801994
# 10/10 [==============================] - 0s 5ms/step
# Epoch 40 , Mean Squared Error: 2.1024717554606394
# 10/10 [==============================] - 0s 5ms/step
# Epoch 41 , Mean Squared Error: 2.1036915116297044
# 10/10 [==============================] - 0s 7ms/step
# Epoch 42 , Mean Squared Error: 2.104866014495139
# 10/10 [==============================] - 0s 4ms/step
# Epoch 43 , Mean Squared Error: 2.105957729781057
# 10/10 [==============================] - 0s 5ms/step
# Epoch 44 , Mean Squared Error: 2.1069622099770955
# 10/10 [==============================] - 0s 5ms/step
# Epoch 45 , Mean Squared Error: 2.107896246914277
# 10/10 [==============================] - 0s 6ms/step
# Epoch 46 , Mean Squared Error: 2.1087731945467185
# 10/10 [==============================] - 0s 4ms/step
# Epoch 47 , Mean Squared Error: 2.109561849532332
# 10/10 [==============================] - 0s 4ms/step
# Epoch 48 , Mean Squared Error: 2.110318209337953
# 10/10 [==============================] - 0s 4ms/step
# Epoch 49 , Mean Squared Error: 2.1109942589703916
# 10/10 [==============================] - 0s 5ms/step
# Epoch 50 , Mean Squared Error: 2.1116903554139386
# 10/10 [==============================] - 0s 5ms/step
# Epoch 51 , Mean Squared Error: 2.1123108988785186
# 10/10 [==============================] - 0s 4ms/step
# Epoch 52 , Mean Squared Error: 2.112872016635967
# 10/10 [==============================] - 0s 4ms/step
# Epoch 53 , Mean Squared Error: 2.113436844772667
# 10/10 [==============================] - 0s 5ms/step
# Epoch 54 , Mean Squared Error: 2.113963218568076
# 10/10 [==============================] - 0s 4ms/step
# Epoch 55 , Mean Squared Error: 2.1144583440808877
# 10/10 [==============================] - 0s 4ms/step
# Epoch 56 , Mean Squared Error: 2.114905705377178
# 10/10 [==============================] - 0s 4ms/step
# Epoch 57 , Mean Squared Error: 2.1153553715190165
# 10/10 [==============================] - 0s 4ms/step
# Epoch 58 , Mean Squared Error: 2.1157702165637584
# 10/10 [==============================] - 0s 4ms/step
# Epoch 59 , Mean Squared Error: 2.1161661623216115
# 10/10 [==============================] - 0s 5ms/step
# Epoch 60 , Mean Squared Error: 2.116523716539483
# 10/10 [==============================] - 0s 5ms/step
# Epoch 61 , Mean Squared Error: 2.116886642737558
# 10/10 [==============================] - 0s 4ms/step
# Epoch 62 , Mean Squared Error: 2.117215168457757
# 10/10 [==============================] - 0s 4ms/step
# Epoch 63 , Mean Squared Error: 2.1175266008576434
# 10/10 [==============================] - 0s 5ms/step
# Epoch 64 , Mean Squared Error: 2.117826385605237
# 10/10 [==============================] - 0s 4ms/step
# Epoch 65 , Mean Squared Error: 2.118117656258872
# 10/10 [==============================] - 0s 8ms/step
# Epoch 66 , Mean Squared Error: 2.118392314932698
# 10/10 [==============================] - 0s 5ms/step
# Epoch 67 , Mean Squared Error: 2.1186504773072525
# 10/10 [==============================] - 0s 10ms/step
# Epoch 68 , Mean Squared Error: 2.118892580104411
# 10/10 [==============================] - 0s 7ms/step
# Epoch 69 , Mean Squared Error: 2.1191393479896443
# 10/10 [==============================] - 0s 4ms/step
# Epoch 70 , Mean Squared Error: 2.1193584101569454
# 10/10 [==============================] - 0s 5ms/step
# Epoch 71 , Mean Squared Error: 2.1195769958399806
# 10/10 [==============================] - 0s 7ms/step
# Epoch 72 , Mean Squared Error: 2.1197874029023267
# 10/10 [==============================] - 0s 5ms/step
# Epoch 73 , Mean Squared Error: 2.1199793472952386
# 10/10 [==============================] - 0s 4ms/step
# Epoch 74 , Mean Squared Error: 2.1201755775574673
# 10/10 [==============================] - 0s 5ms/step
# Epoch 75 , Mean Squared Error: 2.120355893984906
# 10/10 [==============================] - 0s 5ms/step
# Epoch 76 , Mean Squared Error: 2.12052756986225
# 10/10 [==============================] - 0s 4ms/step
# Epoch 77 , Mean Squared Error: 2.120693736217425
# 10/10 [==============================] - 0s 5ms/step
# Epoch 78 , Mean Squared Error: 2.120852326511515
# 10/10 [==============================] - 0s 4ms/step
# Epoch 79 , Mean Squared Error: 2.121005810343891
# 10/10 [==============================] - 0s 5ms/step
# Epoch 80 , Mean Squared Error: 2.1211488778013696
# 10/10 [==============================] - 0s 4ms/step
# Epoch 81 , Mean Squared Error: 2.121293289437094
# 10/10 [==============================] - 0s 4ms/step
# Epoch 82 , Mean Squared Error: 2.1214296923786247
# 10/10 [==============================] - 0s 4ms/step
# Epoch 83 , Mean Squared Error: 2.121562037217785
# 10/10 [==============================] - 0s 4ms/step
# Epoch 84 , Mean Squared Error: 2.1216886871981724
# 10/10 [==============================] - 0s 4ms/step
# Epoch 85 , Mean Squared Error: 2.1218063902348305
# 10/10 [==============================] - 0s 4ms/step
# Epoch 86 , Mean Squared Error: 2.121929002952992
# 10/10 [==============================] - 0s 4ms/step
# Epoch 87 , Mean Squared Error: 2.1220377526805785
# 10/10 [==============================] - 0s 5ms/step
# Epoch 88 , Mean Squared Error: 2.12215037261298
# 10/10 [==============================] - 0s 4ms/step
# Epoch 89 , Mean Squared Error: 2.122255095622069
# 10/10 [==============================] - 0s 5ms/step
# Epoch 90 , Mean Squared Error: 2.122355351201735
# 10/10 [==============================] - 0s 5ms/step
# Epoch 91 , Mean Squared Error: 2.1224509779202756
# 10/10 [==============================] - 0s 5ms/step
# Epoch 92 , Mean Squared Error: 2.1225423475965375
# 10/10 [==============================] - 0s 4ms/step
# Epoch 93 , Mean Squared Error: 2.1226351411240434
# 10/10 [==============================] - 0s 5ms/step
# Epoch 94 , Mean Squared Error: 2.122722172032853
# 10/10 [==============================] - 0s 4ms/step
# Epoch 95 , Mean Squared Error: 2.1228064472735406
# 10/10 [==============================] - 0s 5ms/step
# Epoch 96 , Mean Squared Error: 2.122890446437787
# 10/10 [==============================] - 0s 4ms/step
# Epoch 97 , Mean Squared Error: 2.122965884201482
# 10/10 [==============================] - 0s 4ms/step
# Epoch 98 , Mean Squared Error: 2.1230436786659848
# 10/10 [==============================] - 0s 4ms/step
# Epoch 99 , Mean Squared Error: 2.1231183144829195
# 10/10 [==============================] - 0s 10ms/step
# Epoch 100 , Mean Squared Error: 2.1231915344757275
# [1.4148662843623285, 1.464862382842407, 1.5146606597082681, 1.565791148120289, 1.6145038130192737, 1.6624903573679861, 1.7085538077377365, 1.7516638969485079, 1.7914492016595132, 1.8278804940920237, 1.8600851176211517, 1.88887244226788, 1.9140142062368035, 1.936659357853367, 1.9562073133354372, 1.973708449368592, 1.9887116551354653, 2.002106179591207, 2.0138504916785713, 2.024371743159076, 2.033690317410211, 2.0418452135855234, 2.0491553995248424, 2.055558770782614, 2.0611689930708095, 2.066270268815467, 2.0708028112036656, 2.074887554806804, 2.0786184978109197, 2.0820008571231217, 2.084877514042026, 2.0876371217219756, 2.090126583006053, 2.0923837099442095, 2.0944070100124437, 2.0962743725425024, 2.0980066027170348, 2.0995951190734883, 2.1011046775801994, 2.1024717554606394, 2.1036915116297044, 2.104866014495139, 2.105957729781057, 2.1069622099770955, 2.107896246914277, 2.1087731945467185, 2.109561849532332, 2.110318209337953, 2.1109942589703916, 2.1116903554139386, 2.1123108988785186, 2.112872016635967, 2.113436844772667, 2.113963218568076, 2.1144583440808877, 2.114905705377178, 2.1153553715190165, 2.1157702165637584, 2.1161661623216115, 2.116523716539483, 2.116886642737558, 2.117215168457757, 2.1175266008576434, 2.117826385605237, 2.118117656258872, 2.118392314932698, 2.1186504773072525, 2.118892580104411, 2.1191393479896443, 2.1193584101569454, 2.1195769958399806, 2.1197874029023267, 2.1199793472952386, 2.1201755775574673, 2.120355893984906, 2.12052756986225, 2.120693736217425, 2.120852326511515, 2.121005810343891, 2.1211488778013696, 2.121293289437094, 2.1214296923786247, 2.121562037217785, 2.1216886871981724, 2.1218063902348305, 2.121929002952992, 2.1220377526805785, 2.12215037261298, 2.122255095622069, 2.122355351201735, 2.1224509779202756, 2.1225423475965375, 2.1226351411240434, 2.122722172032853, 2.1228064472735406, 2.122890446437787, 2.122965884201482, 2.1230436786659848, 2.1231183144829195, 2.1231915344757275]
# Mean:  2.044956499666686
# Standard Deviation:  0.15303898429150092

# %% [markdown]
#  AS The number of epochs increases the  average mean squared error increases , this I assume is due to overfitting of the data on the training set , i.e the model is to specific to the training data making it more error prone when intorduced to the test data over a large no of epochs (in this case 100 epochs)
