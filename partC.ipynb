# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
from sklearn.metrics import mean_squared_error

import pandas as pd
from sklearn.model_selection import train_test_split
  
# importing data
df = pd.read_csv('concrete_data.csv')
  
# head of the data
#print(df.head())

#prepare the X independent   variables 

X1 = df['Cement']
X2=df['Blast Furnace Slag']
X3 =df['Fly Ash']
X4=df['Water']
X5=df['Superplasticizer']
X6=df['Coarse Aggregate']
X7=df['Fine Aggregate']
X8=df['Age']
X = pd.concat([X1,X2,X3,X4,X5,X6,X7,X8], axis=1)
#X.head(20)

# %%
#prepare the Y  dependent variables 
Y1 = df['Strength']
Y = pd.concat([Y1], axis=1)
#Y.head(20)

# %%
#Split the data
x_train, x_test,y_train,y_test = train_test_split(X,Y,test_size =0.3)
# print the data
# x_train
# Manually normalize the data for the indepnedent x variables by subtracting the mean and dividing by the standard deviation
x_train_normalized = (x_train - np.mean(x_train, axis=0)) / np.std(x_train, axis=0)
x_test_normalized = (x_test - np.mean(x_train, axis=0)) / np.std(x_train, axis=0)

# Manually normalize the data for the dependent y variables by subtracting the mean and dividing by the standard deviation
y_train_normalized = (y_train - np.mean(y_train, axis=0)) / np.std(y_train, axis=0)
y_test_normalized = (y_test - np.mean(y_train, axis=0)) / np.std(y_train, axis=0)

# Create a neural network model
model = Sequential()
model.add(Dense(10, input_dim=x_train_normalized.shape[1], activation='relu',use_bias=True))  # Hidden layer with 10 nodes and ReLU activation
model.add(Dense(1, activation='sigmoid',use_bias=True))  # Output layer with 1 node and sigmoid activation

# Compile the model
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])

# Train the model with 100 epochs
epochs = 100
mse_list=[]
y_pred_list=[]
for epoch in range(epochs):
    model.fit(x_train_normalized,y_train,epochs=1,verbose=0)
    y_pred = model.predict(x_test_normalized)
    y_pred_list.append(y_pred)
    # print("y_pred : ",y_pred)
    #evaluate model on the normalized test data
    mse = mean_squared_error(y_test_normalized,y_pred)
    mse_list.append(mse)
    print(f"Epoch {epoch +1} , Mean Squared Error: {mse}")
#   List of Mean Squared errors for 50 epochs
print(mse_list) 

# Calculate the mean
mean_mse = np.mean(mse_list)

# Calculate the standard deviation
std_dev_mse = np.std(mse_list)

# Print the results
print("Mean: ", mean_mse)
print("Standard Deviation: ", std_dev_mse)
# print("y_prediction list: " ,y_pred_list)


#observation , decreased mean squared error after normalization
# Out:
# 10/10 [==============================] - 0s 7ms/step
# Epoch 1 , Mean Squared Error: 1.232020420322492
# 10/10 [==============================] - 0s 12ms/step
# Epoch 2 , Mean Squared Error: 1.2488516311826927
# 10/10 [==============================] - 0s 16ms/step
# Epoch 3 , Mean Squared Error: 1.2700185936421908
# 10/10 [==============================] - 0s 17ms/step
# Epoch 4 , Mean Squared Error: 1.2940452913217189
# 10/10 [==============================] - 0s 13ms/step
# Epoch 5 , Mean Squared Error: 1.3199254766452588
# 10/10 [==============================] - 1s 31ms/step
# Epoch 6 , Mean Squared Error: 1.3467886473822648
# 10/10 [==============================] - 0s 11ms/step
# Epoch 7 , Mean Squared Error: 1.3751665346307933
# 10/10 [==============================] - 0s 20ms/step
# Epoch 8 , Mean Squared Error: 1.4019814075282495
# 10/10 [==============================] - 0s 31ms/step
# Epoch 9 , Mean Squared Error: 1.4296254171576053
# 10/10 [==============================] - 1s 28ms/step
# Epoch 10 , Mean Squared Error: 1.4565260772052624
# 10/10 [==============================] - 0s 13ms/step
# Epoch 11 , Mean Squared Error: 1.4832491349938712
# 10/10 [==============================] - 1s 26ms/step
# Epoch 12 , Mean Squared Error: 1.5092662342793701
# 10/10 [==============================] - 1s 40ms/step
# Epoch 13 , Mean Squared Error: 1.5342689957161233
# 10/10 [==============================] - 0s 18ms/step
# Epoch 14 , Mean Squared Error: 1.5591013764584765
# 10/10 [==============================] - 0s 12ms/step
# Epoch 15 , Mean Squared Error: 1.5825374358504434
# 10/10 [==============================] - 0s 24ms/step
# Epoch 16 , Mean Squared Error: 1.6050621603922097
# 10/10 [==============================] - 0s 31ms/step
# Epoch 17 , Mean Squared Error: 1.6268629464391375
# 10/10 [==============================] - 0s 22ms/step
# Epoch 18 , Mean Squared Error: 1.6471345218791187
# 10/10 [==============================] - 0s 13ms/step
# Epoch 19 , Mean Squared Error: 1.6674491415989336
# 10/10 [==============================] - 1s 41ms/step
# Epoch 20 , Mean Squared Error: 1.6858761196781091
# 10/10 [==============================] - 0s 19ms/step
# Epoch 21 , Mean Squared Error: 1.703200539590097
# 10/10 [==============================] - 0s 15ms/step
# Epoch 22 , Mean Squared Error: 1.719648887819172
# 10/10 [==============================] - 0s 13ms/step
# Epoch 23 , Mean Squared Error: 1.7351721367297623
# 10/10 [==============================] - 1s 24ms/step
# Epoch 24 , Mean Squared Error: 1.749799951265764
# 10/10 [==============================] - 1s 26ms/step
# Epoch 25 , Mean Squared Error: 1.763042324951306
# 10/10 [==============================] - 1s 16ms/step
# Epoch 26 , Mean Squared Error: 1.7753568221280769
# 10/10 [==============================] - 0s 10ms/step
# Epoch 27 , Mean Squared Error: 1.7870627999945943
# 10/10 [==============================] - 0s 19ms/step
# Epoch 28 , Mean Squared Error: 1.7974166370801234
# 10/10 [==============================] - 0s 28ms/step
# Epoch 29 , Mean Squared Error: 1.80774902068179
# 10/10 [==============================] - 0s 11ms/step
# Epoch 30 , Mean Squared Error: 1.8169505427431565
# 10/10 [==============================] - 0s 15ms/step
# Epoch 31 , Mean Squared Error: 1.8254946793910773
# 10/10 [==============================] - 0s 20ms/step
# Epoch 32 , Mean Squared Error: 1.8338181847638635
# 10/10 [==============================] - 0s 14ms/step
# Epoch 33 , Mean Squared Error: 1.841282204159183
# 10/10 [==============================] - 0s 14ms/step
# Epoch 34 , Mean Squared Error: 1.848296483602304
# 10/10 [==============================] - 0s 12ms/step
# Epoch 35 , Mean Squared Error: 1.8546093461739512
# 10/10 [==============================] - 0s 16ms/step
# Epoch 36 , Mean Squared Error: 1.8606344077767543
# 10/10 [==============================] - 0s 21ms/step
# Epoch 37 , Mean Squared Error: 1.8661508703115748
# 10/10 [==============================] - 0s 8ms/step
# Epoch 38 , Mean Squared Error: 1.8714842623199537
# 10/10 [==============================] - 0s 17ms/step
# Epoch 39 , Mean Squared Error: 1.8761816930849506
# 10/10 [==============================] - 1s 21ms/step
# Epoch 40 , Mean Squared Error: 1.8806971983639338
# 10/10 [==============================] - 0s 12ms/step
# Epoch 41 , Mean Squared Error: 1.8847534809917312
# 10/10 [==============================] - 0s 13ms/step
# Epoch 42 , Mean Squared Error: 1.8886160254911546
# 10/10 [==============================] - 0s 10ms/step
# Epoch 43 , Mean Squared Error: 1.8921550031685475
# 10/10 [==============================] - 0s 15ms/step
# Epoch 44 , Mean Squared Error: 1.8954542971922448
# 10/10 [==============================] - 0s 10ms/step
# Epoch 45 , Mean Squared Error: 1.8986587053554895
# 10/10 [==============================] - 0s 13ms/step
# Epoch 46 , Mean Squared Error: 1.9015475596842017
# 10/10 [==============================] - 0s 11ms/step
# Epoch 47 , Mean Squared Error: 1.904244530004285
# 10/10 [==============================] - 0s 9ms/step
# Epoch 48 , Mean Squared Error: 1.9068042569798995
# 10/10 [==============================] - 0s 7ms/step
# Epoch 49 , Mean Squared Error: 1.9091206220617032
# 10/10 [==============================] - 0s 8ms/step
# Epoch 50 , Mean Squared Error: 1.9113250820089092
# 10/10 [==============================] - 0s 9ms/step
# Epoch 51 , Mean Squared Error: 1.9133787158375268
# 10/10 [==============================] - 0s 6ms/step
# Epoch 52 , Mean Squared Error: 1.9154119714419726
# 10/10 [==============================] - 0s 10ms/step
# Epoch 53 , Mean Squared Error: 1.9172601144536692
# 10/10 [==============================] - 0s 8ms/step
# Epoch 54 , Mean Squared Error: 1.9189815188825332
# 10/10 [==============================] - 0s 5ms/step
# Epoch 55 , Mean Squared Error: 1.9206713589733682
# 10/10 [==============================] - 0s 5ms/step
# Epoch 56 , Mean Squared Error: 1.9221713966897296
# 10/10 [==============================] - 0s 7ms/step
# Epoch 57 , Mean Squared Error: 1.9236207698195005
# 10/10 [==============================] - 0s 3ms/step
# Epoch 58 , Mean Squared Error: 1.924948182987205
# 10/10 [==============================] - 0s 3ms/step
# Epoch 59 , Mean Squared Error: 1.9262325803506788
# 10/10 [==============================] - 0s 3ms/step
# Epoch 60 , Mean Squared Error: 1.9274881074727788
# 10/10 [==============================] - 0s 3ms/step
# Epoch 61 , Mean Squared Error: 1.9286154668756883
# 10/10 [==============================] - 0s 3ms/step
# Epoch 62 , Mean Squared Error: 1.929671346617705
# 10/10 [==============================] - 0s 3ms/step
# Epoch 63 , Mean Squared Error: 1.9306802300995012
# 10/10 [==============================] - 0s 3ms/step
# Epoch 64 , Mean Squared Error: 1.9316877429355601
# 10/10 [==============================] - 0s 3ms/step
