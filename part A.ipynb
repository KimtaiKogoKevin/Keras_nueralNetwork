# %% [markdown]
# A formal definition of the networks structure , including the number of inputs , number of hidden layers  and number of nodes in the hidden layers as well as the number of node in the output layer.

# %% [markdown]
# Using the numpy library we initialize the weights and the biases to random numbers

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
from sklearn.metrics import mean_squared_error

import pandas as pd
from sklearn.model_selection import train_test_split
  
# importing data
df = pd.read_csv('concrete_data.csv')
  
# head of the data
#print(df.head())

#prepare the X  variables 

X1 = df['Cement']
X2=df['Blast Furnace Slag']
X3 =df['Fly Ash']
X4=df['Water']
X5=df['Superplasticizer']
X6=df['Coarse Aggregate']
X7=df['Fine Aggregate']
X8=df['Age']
X = pd.concat([X1,X2,X3,X4,X5,X6,X7,X8], axis=1)
#X.head(20)



# Prepare your training data and corresponding target labels
#X_train = ...  # Your training data
#y_train = ...  # Your target labels

# %%
#prepare the Y variables 
Y1 = df['Strength']
Y = pd.concat([Y1], axis=1)
#Y.head(20)

# %%
#Split the data
x_train, x_test,y_train,y_test = train_test_split(X,Y,test_size =0.3)
# print the data
x_train

# Create a neural network model
model = Sequential()
model.add(Dense(10, input_dim=x_train.shape[1], activation='relu'))  # Hidden layer with 10 nodes and ReLU activation
model.add(Dense(1, activation='sigmoid'))  # Output layer with 1 node and sigmoid activation

# Compile the model
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])

# Train the model with 50 epochs
epochs = 50
mse_list=[]
for epoch in range(epochs):
    model.fit(x_train,y_train,epochs=1,verbose=0)
    y_pred = model.predict(x_test)
    # print("y_pred : ",y_pred)
    mse = mean_squared_error(y_test,y_pred)
    mse_list.append(mse)
    print(f"Epoch {epoch +1} , Mean Squared Error: {mse}")
#   List of Mean Squared errors for 50 epochs
print(mse_list) 

# Calculate the mean
mean_mse = np.mean(mse_list)

# Calculate the standard deviation
std_dev_mse = np.std(mse_list)

# Print the results
print("Mean: ", mean_mse)
print("Standard Deviation: ", std_dev_mse)
# Out:
# 10/10 [==============================] - 0s 8ms/step
# Epoch 1 , Mean Squared Error: 1553.8075750809062
# 10/10 [==============================] - 0s 10ms/step
# Epoch 2 , Mean Squared Error: 1553.8075750809062
# 10/10 [==============================] - 0s 11ms/step
# Epoch 3 , Mean Squared Error: 1553.8075750809062
# 10/10 [==============================] - 0s 20ms/step
# Epoch 4 , Mean Squared Error: 1553.8075750809062
# 10/10 [==============================] - 1s 23ms/step
# Epoch 5 , Mean Squared Error: 1553.8075750809062
# 10/10 [==============================] - 0s 10ms/step
# Epoch 6 , Mean Squared Error: 1553.8075750809062
# 10/10 [==============================] - 0s 15ms/step
# Epoch 7 , Mean Squared Error: 1553.8075750809062
# 10/10 [==============================] - 0s 27ms/step
# Epoch 8 , Mean Squared Error: 1553.8075750809062
# 10/10 [==============================] - 0s 19ms/step
# Epoch 9 , Mean Squared Error: 1553.8075750809062
# ...
